# %% [markdown]
# # Practice your skills loading data from a CSV file
# In this exercise, you will load a CSV file and you'll perform some operations on it to extract data. If you know how to do this with the Pandas library, you can use that. If not, you can use the csv library with the ready-to-use example this notebook provides.

# %%
import pandas as pd

path = 'sample_data/wine-ratings-small.csv'
data = pd.read_csv(path) 
data
# Out:
#      Unnamed: 0                                          name  grape  \
# 0             0      Laurenz V Charming Gruner Veltliner 2013    NaN
# 1             1      Laurenz V Charming Gruner Veltliner 2014    NaN
# 2             2       Laurenz V Singing Gruner Veltliner 2007    NaN
# 3             3       Laurenz V Singing Gruner Veltliner 2010    NaN
# 4             4       Laurenz V Singing Gruner Veltliner 2011    NaN
# ..          ...                                           ...    ...
# 775         775        Lewis Cellars Syrah Ethan's Blend 2005    NaN
# 776         776        Lewis Cellars Syrah Ethan's Blend 2014    NaN
# 777         777        Lewis Cellars Syrah Ethan's Blend 2009    NaN
# 778         778                       Lexington Apex Red 2011    NaN
# 779         779  Lexington Gist Ranch Cabernet Sauvignon 2011    NaN
#
#                                region     variety  rating  \
# 0                    Kamptal, Austria  White Wine    90.0
# 1                    Kamptal, Austria  White Wine    90.0
# 2                             Austria  White Wine    90.0
# 3                             Austria  White Wine    88.0
# 4                             Austria  White Wine    88.0
# ..                                ...         ...     ...
# 775                        California    Red Wine    92.0
# 776                        California    Red Wine    93.0
# 777                        California    Red Wine    94.0
# 778  Santa Cruz Mountains, California    Red Wine    91.0
# 779  Santa Cruz Mountains, California    Red Wine    91.0
#
#                                                  notes
# 0    Aromas of ripe apples and a typical Veltliner ...
# 1    Aromas of ripe apples and a typical Veltliner ...
# 2    A very attractive fruit bouquet yields apple, ...
# 3    A very attractive fruit bouquet yields apple, ...
# 4    A very attractive fruit bouquet yields apple, ...
# ..                                                 ...
# 775  Now 7 years old, Alec's younger brother Ethan ...
# 776  Born in 2000, everything about Ethan and his n...
# 777  Positioned between brothers, Alec and Mason, E...
# 778          Blend: 99% Cabernet Sauvignon, 1% Merlot
# 779          Blend: 80% Cabernet Sauvignon, 20% Merlot
#
# [780 rows x 7 columns]

# %% [markdown]
# Looping over the list of dictionaries can be tricky with plain Python. Specialized libraries like Pandas make this much easier but the downside is that you need to learn a new library. The following code is a bit more verbose but it's a good exercise to learn how to work with dictionaries in Python.

# %%
# The wines that has 'Napa' as part of its region name.

condicion = []
for i in data.region: condicion.append(True) if 'Napa' in i else condicion.append(False)
napaWines = data[ condicion ]
napaWines
# Out:
#      Unnamed: 0                                               name  grape  \
# 24           24  Lava Vine Winery Napa Valley Cabernet Sauvigno...    NaN
# 25           25  Lava Vine Winery Napa Valley Reserve Cabernet ...    NaN
# 26           26  Lava Vine Winery Napa Valley Reserve Cabernet ...    NaN
# 288         288             Leaping Lizard Cabernet Sauvignon 2007    NaN
# 685         685         Levendi Stagecoach Cabernet Sauvignon 2008    NaN
# ..          ...                                                ...    ...
# 766         766              Lewis Cellars Reserve Chardonnay 2018    NaN
# 767         767              Lewis Cellars Reserve Chardonnay 2017    NaN
# 768         768                  Lewis Cellars Reserve Merlot 1995    NaN
# 769         769                 Lewis Cellars Sauvignon Blanc 2016    NaN
# 770         770                 Lewis Cellars Sauvignon Blanc 2018    NaN
#
#                       region     variety  rating  \
# 24   Napa Valley, California    Red Wine    91.0
# 25   Napa Valley, California    Red Wine    92.0
# 26   Napa Valley, California    Red Wine    92.0
# 288  Napa Valley, California    Red Wine    90.0
# 685  Napa Valley, California    Red Wine    94.0
# ..                       ...         ...     ...
# 766  Napa Valley, California  White Wine    93.0
# 767  Napa Valley, California  White Wine    93.0
# 768  Napa Valley, California    Red Wine    92.0
# 769  Napa Valley, California  White Wine    90.0
# 770  Napa Valley, California  White Wine    92.0
#
#                                                  notes
# 24   A wonderful representation of how amazing the ...
# 25   Black berries and hints of strawberry invite w...
# 26   A slight minty nose with dark chocolate and fr...
# 288  Our Cabernet Sauvignon is a full-bodied, fruit...
# 685  From the Stagecoach Vineyard high on the easte...
# ..                                                 ...
# 766  From the long growing season of 2018, this Nap...
# 767  Think of our 2017 Reserve Chardonnay as a Roll...
# 768  When asked to describe our Reserve Merlot as b...
# 769  The warm, vibrant character and seductive imag...
# 770  Like a sailplane this 2018 Sauvignon Blanc soa...
#
# [79 rows x 7 columns]

# %% [markdown]
# #### Type of wine (red or white)

# %%
print(data.variety.unique())

redWines = data[data.variety == 'Red Wine']
whiteWines = data[data.variety == 'White Wine']

print(len(redWines + whiteWines))

whiteWines
# Out:
# ['White Wine' 'Red Wine' 'Sparkling & Champagne' 'Pink and Rosé' nan
#  'Collectible']
# 766
#      Unnamed: 0                                         name  grape  \
# 0             0     Laurenz V Charming Gruner Veltliner 2013    NaN
# 1             1     Laurenz V Charming Gruner Veltliner 2014    NaN
# 2             2      Laurenz V Singing Gruner Veltliner 2007    NaN
# 3             3      Laurenz V Singing Gruner Veltliner 2010    NaN
# 4             4      Laurenz V Singing Gruner Veltliner 2011    NaN
# ..          ...                                          ...    ...
# 770         770           Lewis Cellars Sauvignon Blanc 2018    NaN
# 771         771         Lewis Cellars Sonoma Chardonnay 2014    NaN
# 772         772         Lewis Cellars Sonoma Chardonnay 2015    NaN
# 773         773         Lewis Cellars Sonoma Chardonnay 2017    NaN
# 774         774  Lewis Cellars Sonoma Valley Chardonnay 2008    NaN
#
#                                        region     variety  rating  \
# 0                            Kamptal, Austria  White Wine    90.0
# 1                            Kamptal, Austria  White Wine    90.0
# 2                                     Austria  White Wine    90.0
# 3                                     Austria  White Wine    88.0
# 4                                     Austria  White Wine    88.0
# ..                                        ...         ...     ...
# 770                   Napa Valley, California  White Wine    92.0
# 771  Russian River, Sonoma County, California  White Wine    93.0
# 772  Russian River, Sonoma County, California  White Wine    92.0
# 773  Russian River, Sonoma County, California  White Wine    92.0
# 774                 Sonoma County, California  White Wine    91.0
#
#                                                  notes
# 0    Aromas of ripe apples and a typical Veltliner ...
# 1    Aromas of ripe apples and a typical Veltliner ...
# 2    A very attractive fruit bouquet yields apple, ...
# 3    A very attractive fruit bouquet yields apple, ...
# 4    A very attractive fruit bouquet yields apple, ...
# ..                                                 ...
# 770  Like a sailplane this 2018 Sauvignon Blanc soa...
# 771  Sourced from 40-year old vines the wine is unu...
# 772  Blazing tropical fruit, exotic spices and sexy...
# 773  Chardonnay is whole cluster pressed, barrel fe...
# 774  Our Sonoma Chardonnay comes from some of the o...
#
# [201 rows x 7 columns]

# %% [markdown]
# ### Wine score range or baseline (e.g. between 90 and 92 points)

# %% [markdown]
# #### **NOTE**: If you are trying to use ratings, remember that you will need to convert the ratings to integers for numerical comparisons.

# %%
intRating = []
for i in data.rating: intRating.append(int(i))
condicion = pd.Series(intRating).between(90,92)
wineScore = data[condicion]
print(wineScore.rating.unique())
wineScore
# Out:
# [90. 91. 92.]
#      Unnamed: 0                                          name  grape  \
# 0             0      Laurenz V Charming Gruner Veltliner 2013    NaN
# 1             1      Laurenz V Charming Gruner Veltliner 2014    NaN
# 2             2       Laurenz V Singing Gruner Veltliner 2007    NaN
# 6             6                   Lava Cap American River Red    NaN
# 7             7                         Lava Cap Barbera 2010    NaN
# ..          ...                                           ...    ...
# 773         773          Lewis Cellars Sonoma Chardonnay 2017    NaN
# 774         774   Lewis Cellars Sonoma Valley Chardonnay 2008    NaN
# 775         775        Lewis Cellars Syrah Ethan's Blend 2005    NaN
# 778         778                       Lexington Apex Red 2011    NaN
# 779         779  Lexington Gist Ranch Cabernet Sauvignon 2011    NaN
#
#                                        region     variety  rating  \
# 0                            Kamptal, Austria  White Wine    90.0
# 1                            Kamptal, Austria  White Wine    90.0
# 2                                     Austria  White Wine    90.0
# 6     El Dorado, Sierra Foothills, California    Red Wine    90.0
# 7                Sierra Foothills, California    Red Wine    90.0
# ..                                        ...         ...     ...
# 773  Russian River, Sonoma County, California  White Wine    92.0
# 774                 Sonoma County, California  White Wine    91.0
# 775                                California    Red Wine    92.0
# 778          Santa Cruz Mountains, California    Red Wine    91.0
# 779          Santa Cruz Mountains, California    Red Wine    91.0
#
#                                                  notes
# 0    Aromas of ripe apples and a typical Veltliner ...
# 1    Aromas of ripe apples and a typical Veltliner ...
# 2    A very attractive fruit bouquet yields apple, ...
# 6    This wine was created as a table wine. We want...
# 7    The plump, rich cherry, raspberry and plum fru...
# ..                                                 ...
# 773  Chardonnay is whole cluster pressed, barrel fe...
# 774  Our Sonoma Chardonnay comes from some of the o...
# 775  Now 7 years old, Alec's younger brother Ethan ...
# 778          Blend: 99% Cabernet Sauvignon, 1% Merlot
# 779          Blend: 80% Cabernet Sauvignon, 20% Merlot
#
# [514 rows x 7 columns]

# %%
napaWines.to_json('napa_wines.json', orient='records', lines=True)
wineScore.to_json('wine_score.json', orient='records', lines=True)
